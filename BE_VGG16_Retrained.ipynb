# %%
import os
import sys
import datetime
import glob as glob
import numpy as np
import cv2
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, GlobalAveragePooling2D, Flatten
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.applications.vgg16 import VGG16, preprocess_input
from keras import layers, models
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

from sklearn import svm
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # CNN + SVM 2 - only keep input layer

# %%
from keras.preprocessing.image import ImageDataGenerator

train_data_dir = 'Polyp_copy/train'
validation_data_dir = 'Polyp_copy/validation'

# Image generation 
train_datagen = ImageDataGenerator(
     rescale=1./255,
      rotation_range=45,
      width_shift_range=0.3,
     height_shift_range=0.3,
      horizontal_flip=True,
     fill_mode='nearest'
)
 # Image generation 

validation_datagen = ImageDataGenerator(
     rescale=1./255,
     rotation_range=45,
      width_shift_range=0.3,
    height_shift_range=0.3,
      horizontal_flip=True,
     fill_mode='nearest'
)
 
# set our batch size (typically on most mid tier systems we'll use 16-32)
batch_size = 25

 # Standardize image size
img_rows, img_cols = 224, 224 

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 300 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
Pre_trained_model = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))

for layer in Pre_trained_model.layers[:2]:
    print(layer.name)
    layer.trainable = False

print()

for layer in Pre_trained_model.layers[2:]:
    print(layer.name)
    layer.trainable = True


    
print(len(Pre_trained_model.layers))
# Out:
# Metal device set to: Apple M1
# 2023-03-23 23:12:52.257563: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-23 23:12:52.257895: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# input_1
# block1_conv1
#
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool
# 19

# %%
Pre_trained_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,712,896
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
last_layer = Pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 7, 7, 512)

# %%
# DEFINE the Model
# Flatten the output layer to 1 dimension
x = layers.GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(2, activation='sigmoid')(x)

# Configure and compile the model

model = tf.keras.Model(Pre_trained_model.input, x)

# optimizer = Adam(learning_rate=0.001)
optimizer = SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['acc'])


# model.compile(
#             optimizer=keras.optimizers.Adadelta(),
#             loss='sparse_categorical_crossentropy',
#             metrics=['sparse_categorical_accuracy'])

# Use VGG16 as feature extraction tool and then pass the output of pretrained model as input
# Argue that you improve Random Forest Classifier - pass better features to classifier so it improves
# Get features out of VGG16 and then pass them to Random Forest Classifier

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 14,978,370
# Trainable params: 14,976,578
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
#Training the MODEL Feature-Extraction
#If performing fine tuning directly would result in a huge gradient, so it's better that we perform 3 epochs of 
# feature extraction first so that weights of the final fully connected layer aren't completely random. 
#The intuition for this is that if we don't perform feature-extraction, then the gradient will be too large
#and will change the pretrained weights too much.
# Enter the number of training and validation samples here
nb_train_samples = 300
nb_validation_samples = 100

# We only train 5 EPOCHS 
epochs = 70
# batch_size = 25

r = model.fit(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# Epoch 1/70
# 2023-03-23 23:12:53.406311: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-23 23:12:53.916155: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 0.8295 - acc: 0.5267
# 2023-03-23 23:13:39.688587: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 52s 4s/step - loss: 0.8295 - acc: 0.5267 - val_loss: 0.6523 - val_acc: 0.5500
# Epoch 2/70
# 12/12 [==============================] - 52s 4s/step - loss: 0.7316 - acc: 0.5733 - val_loss: 0.6413 - val_acc: 0.6500
# Epoch 3/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.7111 - acc: 0.5367 - val_loss: 0.6151 - val_acc: 0.7100
# Epoch 4/70
# 12/12 [==============================] - 25s 2s/step - loss: 0.6710 - acc: 0.6333 - val_loss: 0.6097 - val_acc: 0.7200
# Epoch 5/70
# 12/12 [==============================] - 25s 2s/step - loss: 0.6428 - acc: 0.6333 - val_loss: 0.6033 - val_acc: 0.6800
# Epoch 6/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.6154 - acc: 0.6900 - val_loss: 0.5862 - val_acc: 0.7000
# Epoch 7/70
# 12/12 [==============================] - 25s 2s/step - loss: 0.6116 - acc: 0.6700 - val_loss: 0.5796 - val_acc: 0.6900
# Epoch 8/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.6156 - acc: 0.6900 - val_loss: 0.5692 - val_acc: 0.7200
# Epoch 9/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.5920 - acc: 0.6867 - val_loss: 0.5599 - val_acc: 0.6700
# Epoch 10/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.5668 - acc: 0.7233 - val_loss: 0.5603 - val_acc: 0.7300
# Epoch 11/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.5684 - acc: 0.7167 - val_loss: 0.5347 - val_acc: 0.7100
# Epoch 12/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.5442 - acc: 0.6967 - val_loss: 0.5577 - val_acc: 0.6900
# Epoch 13/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.5285 - acc: 0.7533 - val_loss: 0.5280 - val_acc: 0.7100
# Epoch 14/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.5292 - acc: 0.7567 - val_loss: 0.5240 - val_acc: 0.7700
# Epoch 15/70
# 12/12 [==============================] - 45s 4s/step - loss: 0.5051 - acc: 0.7833 - val_loss: 0.5134 - val_acc: 0.7100
# Epoch 16/70
# 12/12 [==============================] - 52s 4s/step - loss: 0.4928 - acc: 0.7800 - val_loss: 0.5847 - val_acc: 0.6900
# Epoch 17/70
# 12/12 [==============================] - 55s 5s/step - loss: 0.4905 - acc: 0.7667 - val_loss: 0.4904 - val_acc: 0.8000
# Epoch 18/70
# 12/12 [==============================] - 52s 4s/step - loss: 0.4887 - acc: 0.7367 - val_loss: 0.4863 - val_acc: 0.7700
# Epoch 19/70
# 12/12 [==============================] - 54s 4s/step - loss: 0.4599 - acc: 0.7933 - val_loss: 0.4656 - val_acc: 0.7900
# Epoch 20/70
# 12/12 [==============================] - 56s 5s/step - loss: 0.4807 - acc: 0.7767 - val_loss: 0.5007 - val_acc: 0.7600
# Epoch 21/70
# 12/12 [==============================] - 57s 5s/step - loss: 0.4331 - acc: 0.8100 - val_loss: 0.4443 - val_acc: 0.7900
# Epoch 22/70
# 12/12 [==============================] - 56s 5s/step - loss: 0.4512 - acc: 0.7967 - val_loss: 0.4915 - val_acc: 0.7700
# Epoch 23/70
# 12/12 [==============================] - 58s 5s/step - loss: 0.4579 - acc: 0.7967 - val_loss: 0.4504 - val_acc: 0.8000
# Epoch 24/70
# 12/12 [==============================] - 57s 5s/step - loss: 0.4610 - acc: 0.7933 - val_loss: 0.4527 - val_acc: 0.8500
# Epoch 25/70
# 12/12 [==============================] - 56s 5s/step - loss: 0.4162 - acc: 0.8133 - val_loss: 0.4241 - val_acc: 0.8100
# Epoch 26/70
# 12/12 [==============================] - 994s 90s/step - loss: 0.4362 - acc: 0.7833 - val_loss: 0.4186 - val_acc: 0.8700
# Epoch 27/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.3878 - acc: 0.8567 - val_loss: 0.3954 - val_acc: 0.8200
# Epoch 28/70
# 12/12 [==============================] - 341s 31s/step - loss: 0.4148 - acc: 0.8067 - val_loss: 0.5033 - val_acc: 0.7800
# Epoch 29/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.4319 - acc: 0.8067 - val_loss: 0.4134 - val_acc: 0.7900
# Epoch 30/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.3901 - acc: 0.8367 - val_loss: 0.3895 - val_acc: 0.8200
# Epoch 31/70
# 12/12 [==============================] - 34s 3s/step - loss: 0.3655 - acc: 0.8533 - val_loss: 0.3608 - val_acc: 0.8300
# Epoch 32/70
# 12/12 [==============================] - 38s 3s/step - loss: 0.3601 - acc: 0.8633 - val_loss: 0.3503 - val_acc: 0.8600
# Epoch 33/70
# 12/12 [==============================] - 980s 87s/step - loss: 0.3426 - acc: 0.8600 - val_loss: 0.3321 - val_acc: 0.8600
# Epoch 34/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.3530 - acc: 0.8433 - val_loss: 0.4164 - val_acc: 0.8200
# Epoch 35/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.3336 - acc: 0.8633 - val_loss: 0.3059 - val_acc: 0.8600
# Epoch 36/70
# 12/12 [==============================] - 36s 3s/step - loss: 0.3702 - acc: 0.8500 - val_loss: 0.3306 - val_acc: 0.8700
# Epoch 37/70
# 12/12 [==============================] - 38s 3s/step - loss: 0.2794 - acc: 0.9000 - val_loss: 0.3228 - val_acc: 0.8600
# Epoch 38/70
# 12/12 [==============================] - 40s 3s/step - loss: 0.3072 - acc: 0.8600 - val_loss: 0.3156 - val_acc: 0.8300
# Epoch 39/70
# 12/12 [==============================] - 967s 88s/step - loss: 0.2622 - acc: 0.9033 - val_loss: 0.4813 - val_acc: 0.8000
# Epoch 40/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.2933 - acc: 0.8900 - val_loss: 0.2805 - val_acc: 0.8700
# Epoch 41/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.2630 - acc: 0.8967 - val_loss: 0.6148 - val_acc: 0.7300
# Epoch 42/70
# 12/12 [==============================] - 34s 3s/step - loss: 0.3638 - acc: 0.8433 - val_loss: 0.2847 - val_acc: 0.8600
# Epoch 43/70
# 12/12 [==============================] - 1007s 91s/step - loss: 0.2671 - acc: 0.8967 - val_loss: 0.2676 - val_acc: 0.8700
# Epoch 44/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.2120 - acc: 0.9167 - val_loss: 0.2243 - val_acc: 0.9100
# Epoch 45/70
# 12/12 [==============================] - 30s 3s/step - loss: 0.2455 - acc: 0.9133 - val_loss: 0.2975 - val_acc: 0.8500
# Epoch 46/70
# 12/12 [==============================] - 30s 3s/step - loss: 0.2117 - acc: 0.9267 - val_loss: 0.2529 - val_acc: 0.9000
# Epoch 47/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.1878 - acc: 0.9467 - val_loss: 0.2545 - val_acc: 0.9100
# Epoch 48/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.2711 - acc: 0.8900 - val_loss: 0.2490 - val_acc: 0.9100
# Epoch 49/70
# 12/12 [==============================] - 32s 3s/step - loss: 0.2746 - acc: 0.8733 - val_loss: 0.2614 - val_acc: 0.9000
# Epoch 50/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.1833 - acc: 0.9367 - val_loss: 0.1809 - val_acc: 0.9300
# Epoch 51/70
# 12/12 [==============================] - 32s 3s/step - loss: 0.2272 - acc: 0.9167 - val_loss: 0.3581 - val_acc: 0.8200
# Epoch 52/70
# 12/12 [==============================] - 26s 2s/step - loss: 0.2153 - acc: 0.9033 - val_loss: 0.3428 - val_acc: 0.8600
# Epoch 53/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1968 - acc: 0.9100 - val_loss: 0.2086 - val_acc: 0.9100
# Epoch 54/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1662 - acc: 0.9433 - val_loss: 0.3306 - val_acc: 0.8500
# Epoch 55/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1568 - acc: 0.9567 - val_loss: 0.2130 - val_acc: 0.9200
# Epoch 56/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1828 - acc: 0.9300 - val_loss: 0.1984 - val_acc: 0.8800
# Epoch 57/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.2229 - acc: 0.9200 - val_loss: 0.1758 - val_acc: 0.9500
# Epoch 58/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1216 - acc: 0.9633 - val_loss: 0.2044 - val_acc: 0.9100
# Epoch 59/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1182 - acc: 0.9733 - val_loss: 0.1874 - val_acc: 0.9100
# Epoch 60/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.2075 - acc: 0.9167 - val_loss: 0.1839 - val_acc: 0.9100
# Epoch 61/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1174 - acc: 0.9667 - val_loss: 0.1799 - val_acc: 0.9200
# Epoch 62/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.2229 - acc: 0.9167 - val_loss: 0.2106 - val_acc: 0.9100
# Epoch 63/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1065 - acc: 0.9800 - val_loss: 0.1975 - val_acc: 0.9200
# Epoch 64/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.1078 - acc: 0.9633 - val_loss: 0.2498 - val_acc: 0.9200
# Epoch 65/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1321 - acc: 0.9467 - val_loss: 0.1734 - val_acc: 0.9300
# Epoch 66/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.1036 - acc: 0.9800 - val_loss: 0.1823 - val_acc: 0.9300
# Epoch 67/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.1265 - acc: 0.9567 - val_loss: 0.2711 - val_acc: 0.8900
# Epoch 68/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.0836 - acc: 0.9833 - val_loss: 0.1894 - val_acc: 0.8900
# Epoch 69/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.1176 - acc: 0.9600 - val_loss: 0.2549 - val_acc: 0.8900
# Epoch 70/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.1410 - acc: 0.9533 - val_loss: 0.1659 - val_acc: 0.9300

# %%
plt.plot(r.history['acc'])
plt.plot(r.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
df1 = pd.DataFrame(r.history['acc']) 
df2 = pd.DataFrame(r.history['val_acc'])
df3 = pd.DataFrame(r.history['loss'])
df4 = pd.DataFrame(r.history['val_loss'])



df1.to_csv('rt_acc1.csv', header = False)
df2.to_csv('rt_Vacc1.csv', header = False)
df3.to_csv('rt_loss1.csv', header = False)
df4.to_csv('rt_Vloss1.csv', header = False)
