# %%
import os
import sys
import datetime
import glob as glob
import numpy as np
import cv2
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, GlobalAveragePooling2D, Flatten
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.applications.vgg16 import VGG16, preprocess_input
from keras import layers, models
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

from sklearn import svm
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # CNN + SVM - only train the classifier

# %%
from keras.preprocessing.image import ImageDataGenerator

train_data_dir = 'Polyp_copy/train'
validation_data_dir = 'Polyp_copy/validation'

# Image generation 
train_datagen = ImageDataGenerator(
     rescale=1./255,
      rotation_range=45,
      width_shift_range=0.3,
     height_shift_range=0.3,
      horizontal_flip=True,
     fill_mode='nearest'
)
 # Image generation 

validation_datagen = ImageDataGenerator(
     rescale=1./255,
     rotation_range=45,
      width_shift_range=0.3,
    height_shift_range=0.3,
      horizontal_flip=True,
     fill_mode='nearest'
)
 
# set our batch size
batch_size = 25

 # Standardize image size (size of ImageNet images)
img_rows, img_cols = 224, 224 

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 300 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
Pre_trained_model = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))

# Freeze all layers
for layer in Pre_trained_model.layers:
    print(layer.name)
    layer.trainable = False

print()
print(len(Pre_trained_model.layers))
# Out:
# input_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool
#
# 19

# %%
Pre_trained_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
last_layer = Pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape: (None, 7, 7, 512)

# %%
# DEFINE the Model
# Flatten the output layer to 1 dimension
x = layers.GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(2, activation='sigmoid')(x)

# Configure and compile the model

model = tf.keras.Model(Pre_trained_model.input, x)

# optimizer = Adam(learning_rate=0.001)
optimizer = SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_max_pooling2d_1 (Glo  (None, 512)              0
#  balMaxPooling2D)
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 14,978,370
# Trainable params: 263,682
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Training the MODEL Feature-Extraction
# Enter the number of training and validation samples here
nb_train_samples = 300
nb_validation_samples = 100

# Train 70 EPOCHS 
epochs = 70

r = model.fit(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# Epoch 1/70
# 2023-03-23 23:19:36.974710: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 0.8335 - acc: 0.4333
# 2023-03-23 23:20:00.779451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 31s 2s/step - loss: 0.8335 - acc: 0.4333 - val_loss: 0.7347 - val_acc: 0.4900
# Epoch 2/70
# 12/12 [==============================] - 26s 2s/step - loss: 0.7800 - acc: 0.5233 - val_loss: 0.7142 - val_acc: 0.4900
# Epoch 3/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.7738 - acc: 0.4833 - val_loss: 0.7161 - val_acc: 0.5000
# Epoch 4/70
# 12/12 [==============================] - 25s 2s/step - loss: 0.7382 - acc: 0.5267 - val_loss: 0.6932 - val_acc: 0.5800
# Epoch 5/70
# 12/12 [==============================] - 28s 2s/step - loss: 0.7580 - acc: 0.4867 - val_loss: 0.6864 - val_acc: 0.5600
# Epoch 6/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.7445 - acc: 0.5200 - val_loss: 0.6981 - val_acc: 0.5800
# Epoch 7/70
# 12/12 [==============================] - 29s 2s/step - loss: 0.7351 - acc: 0.5067 - val_loss: 0.6911 - val_acc: 0.5400
# Epoch 8/70
# 12/12 [==============================] - 28s 2s/step - loss: 0.7609 - acc: 0.4667 - val_loss: 0.6781 - val_acc: 0.6000
# Epoch 9/70
# 12/12 [==============================] - 28s 2s/step - loss: 0.7325 - acc: 0.5233 - val_loss: 0.6695 - val_acc: 0.6500
# Epoch 10/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.7135 - acc: 0.5367 - val_loss: 0.6744 - val_acc: 0.5900
# Epoch 11/70
# 12/12 [==============================] - 29s 2s/step - loss: 0.7265 - acc: 0.5500 - val_loss: 0.6863 - val_acc: 0.5800
# Epoch 12/70
# 12/12 [==============================] - 30s 3s/step - loss: 0.6960 - acc: 0.5833 - val_loss: 0.6725 - val_acc: 0.6400
# Epoch 13/70
# 12/12 [==============================] - 29s 2s/step - loss: 0.7037 - acc: 0.5533 - val_loss: 0.6755 - val_acc: 0.5700
# Epoch 14/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.7123 - acc: 0.5267 - val_loss: 0.6669 - val_acc: 0.6400
# Epoch 15/70
# 12/12 [==============================] - 30s 3s/step - loss: 0.6967 - acc: 0.5367 - val_loss: 0.6583 - val_acc: 0.6600
# Epoch 16/70
# 12/12 [==============================] - 31s 3s/step - loss: 0.6956 - acc: 0.5633 - val_loss: 0.6700 - val_acc: 0.6100
# Epoch 17/70
# 12/12 [==============================] - 29s 2s/step - loss: 0.6807 - acc: 0.5967 - val_loss: 0.6669 - val_acc: 0.6700
# Epoch 18/70
# 12/12 [==============================] - 29s 2s/step - loss: 0.6904 - acc: 0.5933 - val_loss: 0.6538 - val_acc: 0.6700
# Epoch 19/70
# 12/12 [==============================] - 27s 2s/step - loss: 0.6789 - acc: 0.6267 - val_loss: 0.6558 - val_acc: 0.6100
# Epoch 20/70
# 12/12 [==============================] - 30s 3s/step - loss: 0.6824 - acc: 0.5933 - val_loss: 0.6543 - val_acc: 0.6500
# Epoch 21/70
# 12/12 [==============================] - 28s 2s/step - loss: 0.6626 - acc: 0.6233 - val_loss: 0.6427 - val_acc: 0.6900
# Epoch 22/70
# 12/12 [==============================] - 32s 3s/step - loss: 0.6640 - acc: 0.6367 - val_loss: 0.6325 - val_acc: 0.7100
# Epoch 23/70
# 12/12 [==============================] - 961s 87s/step - loss: 0.6638 - acc: 0.6100 - val_loss: 0.6367 - val_acc: 0.6500
# Epoch 24/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6731 - acc: 0.6133 - val_loss: 0.6425 - val_acc: 0.6600
# Epoch 25/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6733 - acc: 0.5867 - val_loss: 0.6397 - val_acc: 0.7000
# Epoch 26/70
# 12/12 [==============================] - 328s 30s/step - loss: 0.6516 - acc: 0.6200 - val_loss: 0.6476 - val_acc: 0.7000
# Epoch 27/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6553 - acc: 0.6433 - val_loss: 0.6275 - val_acc: 0.6400
# Epoch 28/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6539 - acc: 0.6033 - val_loss: 0.6424 - val_acc: 0.6600
# Epoch 29/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6490 - acc: 0.6600 - val_loss: 0.6418 - val_acc: 0.6600
# Epoch 30/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6448 - acc: 0.6600 - val_loss: 0.6384 - val_acc: 0.7000
# Epoch 31/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6484 - acc: 0.6100 - val_loss: 0.6297 - val_acc: 0.6800
# Epoch 32/70
# 12/12 [==============================] - 18s 2s/step - loss: 0.6312 - acc: 0.6833 - val_loss: 0.6285 - val_acc: 0.7100
# Epoch 33/70
# 12/12 [==============================] - 21s 2s/step - loss: 0.6302 - acc: 0.6533 - val_loss: 0.6298 - val_acc: 0.7200
# Epoch 34/70
# 12/12 [==============================] - 37s 3s/step - loss: 0.6297 - acc: 0.6867 - val_loss: 0.6411 - val_acc: 0.6400
# Epoch 35/70
# 12/12 [==============================] - 949s 86s/step - loss: 0.6437 - acc: 0.6167 - val_loss: 0.6181 - val_acc: 0.7000
# Epoch 36/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6488 - acc: 0.6267 - val_loss: 0.6222 - val_acc: 0.6700
# Epoch 37/70
# 12/12 [==============================] - 18s 1s/step - loss: 0.6279 - acc: 0.6833 - val_loss: 0.6241 - val_acc: 0.7000
# Epoch 38/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6403 - acc: 0.6467 - val_loss: 0.6220 - val_acc: 0.7100
# Epoch 39/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6349 - acc: 0.6300 - val_loss: 0.6164 - val_acc: 0.7000
# Epoch 40/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6298 - acc: 0.6400 - val_loss: 0.6119 - val_acc: 0.6900
# Epoch 41/70
# 12/12 [==============================] - 19s 2s/step - loss: 0.6348 - acc: 0.6533 - val_loss: 0.6175 - val_acc: 0.7100
# Epoch 42/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.6214 - acc: 0.6500 - val_loss: 0.6139 - val_acc: 0.6900
# Epoch 43/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.6147 - acc: 0.6733 - val_loss: 0.6107 - val_acc: 0.6900
# Epoch 44/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.6230 - acc: 0.7067 - val_loss: 0.6180 - val_acc: 0.6800
# Epoch 45/70
# 12/12 [==============================] - 22s 2s/step - loss: 0.6155 - acc: 0.6633 - val_loss: 0.6150 - val_acc: 0.6800
# Epoch 46/70
# 12/12 [==============================] - 24s 2s/step - loss: 0.6173 - acc: 0.6733 - val_loss: 0.6028 - val_acc: 0.7100
# Epoch 47/70
# 12/12 [==============================] - 946s 1s/step - loss: 0.6148 - acc: 0.6900 - val_loss: 0.6183 - val_acc: 0.7000
# Epoch 48/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6344 - acc: 0.6000 - val_loss: 0.6147 - val_acc: 0.6900
# Epoch 49/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.6071 - acc: 0.6633 - val_loss: 0.6188 - val_acc: 0.6600
# Epoch 50/70
# 12/12 [==============================] - 18s 1s/step - loss: 0.6115 - acc: 0.6967 - val_loss: 0.6053 - val_acc: 0.7000
# Epoch 51/70
# 12/12 [==============================] - 15s 1s/step - loss: 0.6024 - acc: 0.7067 - val_loss: 0.6160 - val_acc: 0.6800
# Epoch 52/70
# 12/12 [==============================] - 19s 2s/step - loss: 0.6096 - acc: 0.7067 - val_loss: 0.6139 - val_acc: 0.6900
# Epoch 53/70
# 12/12 [==============================] - 19s 2s/step - loss: 0.6015 - acc: 0.6767 - val_loss: 0.6046 - val_acc: 0.6900
# Epoch 54/70
# 12/12 [==============================] - 990s 90s/step - loss: 0.6163 - acc: 0.6700 - val_loss: 0.6069 - val_acc: 0.7400
# Epoch 55/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.5952 - acc: 0.6833 - val_loss: 0.6101 - val_acc: 0.6900
# Epoch 56/70
# 12/12 [==============================] - 18s 2s/step - loss: 0.6073 - acc: 0.6733 - val_loss: 0.6132 - val_acc: 0.6900
# Epoch 57/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.5980 - acc: 0.6900 - val_loss: 0.5944 - val_acc: 0.7100
# Epoch 58/70
# 12/12 [==============================] - 18s 1s/step - loss: 0.5989 - acc: 0.6767 - val_loss: 0.6028 - val_acc: 0.7100
# Epoch 59/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.6052 - acc: 0.6900 - val_loss: 0.5886 - val_acc: 0.7100
# Epoch 60/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.5931 - acc: 0.6767 - val_loss: 0.6046 - val_acc: 0.6900
# Epoch 61/70
# 12/12 [==============================] - 18s 2s/step - loss: 0.6126 - acc: 0.6567 - val_loss: 0.6066 - val_acc: 0.6800
# Epoch 62/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.5962 - acc: 0.6900 - val_loss: 0.6050 - val_acc: 0.7100
# Epoch 63/70
# 12/12 [==============================] - 18s 1s/step - loss: 0.5864 - acc: 0.7100 - val_loss: 0.6014 - val_acc: 0.6800
# Epoch 64/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.5991 - acc: 0.6900 - val_loss: 0.6042 - val_acc: 0.7300
# Epoch 65/70
# 12/12 [==============================] - 18s 1s/step - loss: 0.5863 - acc: 0.7233 - val_loss: 0.5912 - val_acc: 0.6900
# Epoch 66/70
# 12/12 [==============================] - 16s 1s/step - loss: 0.5980 - acc: 0.6967 - val_loss: 0.5834 - val_acc: 0.7000
# Epoch 67/70
# 12/12 [==============================] - 20s 2s/step - loss: 0.5723 - acc: 0.7400 - val_loss: 0.5986 - val_acc: 0.6700
# Epoch 68/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.5936 - acc: 0.6967 - val_loss: 0.6025 - val_acc: 0.6700
# Epoch 69/70
# 12/12 [==============================] - 17s 1s/step - loss: 0.5799 - acc: 0.7033 - val_loss: 0.6094 - val_acc: 0.6900
# Epoch 70/70
# 12/12 [==============================] - 18s 2s/step - loss: 0.5945 - acc: 0.7100 - val_loss: 0.6057 - val_acc: 0.6700

# %%
plt.plot(r.history['acc'])
plt.plot(r.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
